# %% [markdown]
# # 18 jully 2022

# %%
import pandas as pd 
import numpy as np 

df = pd.read_csv('car.csv')
print(df)
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
df.head(7)
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
# 5       6          2                  audi fox      gas        std        two
# 6       7          1                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# ...

# %%
#
df.tail(3)
# Out:
#      car_ID  symboling      CarName fueltype aspiration doornumber carbody  \
# 202     203         -1  volvo 244dl      gas        std       four   sedan
# 203     204         -1    volvo 246   diesel      turbo       four   sedan
# 204     205         -1  volvo 264gl      gas      turbo       four   sedan
#
#     drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 202        rwd          front      109.1  ...         173        mpfi
# 203        rwd          front      109.1  ...         145         idi
# 204        rwd          front      109.1  ...         141        mpfi
#
#      boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 202       3.58    2.87              8.8        134     5500      18
# 203       3.01    3.40             23.0        106     4800      26
# 204       3.78    3.15              9.5        114     5400      19
#
#      highwaympg    price
# 202          23  21485.0
# 203          27  22470.0
# 204          25  22625.0
# ...

# %%
#calulate mean,median,mode 
df["price"].mean()
# Out:
# 13276.710570731706

# %%
df["stroke"].median()
# Out:
# 3.29

# %%
df["symboling"].mode()
# Out:
# 0    0
# dtype: int64

# %%
#check dtype 
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#name the columns in the data set which have object data type 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
print["CarName"].
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11764/2927878362.py in <module>
# ----> 1 print["CarName"]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
#what is EDA? why it is important

# %%
#what are outliners ? what are methods to detect

# %%
#check null value
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
#drop the column 
df.drop('CarName', inplace=True,axis=1)

# %%
df
# Out:
#      car_ID  symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0         1          3      gas        std        two  convertible        rwd
# 1         2          3      gas        std        two  convertible        rwd
# 2         3          1      gas        std        two    hatchback        rwd
# 3         4          2      gas        std       four        sedan        fwd
# 4         5          2      gas        std       four        sedan        4wd
# ..      ...        ...      ...        ...        ...          ...        ...
# 200     201         -1      gas        std       four        sedan        rwd
# 201     202         -1      gas      turbo       four        sedan        rwd
# 202     203         -1      gas        std       four        sedan        rwd
# 203     204         -1   diesel      turbo       four        sedan        rwd
# 204     205         -1      gas      turbo       four        sedan        rwd
#
# ...

# %%
#rename a colunm 
df.rename(columns = {'symboling':'sy','horsepower':'hp'},inplace=True)

# %%
df
# Out:
#      car_ID  sy fueltype aspiration doornumber      carbody drivewheel  \
# 0         1   3      gas        std        two  convertible        rwd
# 1         2   3      gas        std        two  convertible        rwd
# 2         3   1      gas        std        two    hatchback        rwd
# 3         4   2      gas        std       four        sedan        fwd
# 4         5   2      gas        std       four        sedan        4wd
# ..      ...  ..      ...        ...        ...          ...        ...
# 200     201  -1      gas        std       four        sedan        rwd
# 201     202  -1      gas      turbo       four        sedan        rwd
# 202     203  -1      gas        std       four        sedan        rwd
# 203     204  -1   diesel      turbo       four        sedan        rwd
# 204     205  -1      gas      turbo       four        sedan        rwd
#
#     enginelocation  wheelbase  carlength  ...  enginesize  fuelsystem  \
# ...

# %%
#plot the box plot(detect the outliner)
import seaborn as sns

# %%
sns.boxplot('price', data=df)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price'>

# %%
q1 = df.quantile(0.25)
q3 = df.quantile(0.75)
iqr = q3-q1
c = iqr
print(c)
# Out:
# car_ID               102.00
# sy                     2.00
# wheelbase              7.90
# carlength             16.80
# carwidth               2.80
# carheight              3.50
# curbweight           790.00
# enginesize            44.00
# boreratio              0.43
# stroke                 0.30
# compressionratio       0.80
# hp                    46.00
# peakrpm              700.00
# citympg               11.00
# highwaympg             9.00
# price               8715.00
# dtype: float64

# %%
#what is covariance and correletion?
#what is variance and sd ? what is the difference between both?
#they are two terms which are exactly opposite to each other. 
#covariance gives us direction but not the destination. 
#correlation gives us direction with strength to reach destination.

# %%
#write a python function to check if the number is even 
#python program to generate the 4 table 
for num in range(4,42,4):
    print(num)
# Out:
# 4
# 8
# 12
# 16
# 20
# 24
# 28
# 32
# 36
# 40

# %%
#create a dictionary and convert it into a dataframe
import pandas as pd
data = {'name':['joe','jojo','nick','kiki'],
       'age': [5,4,3,2]}

# %%
df2 = pd.DataFrame.from_dict(data)

# %%
df2
# Out:
#    name  age
# 0   joe    5
# 1  jojo    4
# 2  nick    3
# 3  kiki    2

# %%
#difference between list and tuple 
#list are mutuble

# %%
#String = 'python is fun programming lang,""?
